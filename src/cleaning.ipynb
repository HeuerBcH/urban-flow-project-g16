# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
semaforos_df = pd.read_csv("../data/raw/lista-de-semaforos.csv")

equip_med_vel_df = pd.read_csv("../data/raw/equipamentos-de-medicao-de-velocidade.csv")

equip_fisc_df = pd.read_csv("../data/raw/equipamentos-fiscalizacao.csv")

equip_fisc_df.head()
# Out:
#    _id equipamento     tipo  \
# 0    1        5941  Lombada
# 1    2        5942  Lombada
# 2    3        5943  Lombada
# 3    4        5944  Lombada
# 4    5        5945  Lombada
#
#                                           logradouro velocidade_via  latitude  \
# 0  AV. MAL. MASCARENHAS DE MORAES, EM FRENTE AERO...        60 km/h -8.130970
# 1  AV. MAL. MASCARENHAS DE MORAES, EM FRENTE AERO...        60 km/h -8.130647
# 2                   AV. BOA VIAGEM - TERCEIRO JARDIM        60 km/h -8.107843
# 3  DEFRONTE A PCA. GOV. PAULO GUERRA, CABANGA - S...        60 km/h -8.080121
# 4  APOS PONTE AGAMENON MAGALHAES, CABANGA - SENT....        60 km/h -8.080820
#
#    longitude
# 0 -34.916161
# 1 -34.915886
# 2 -34.888161
# 3 -34.892187
# 4 -34.891159
